# %%
# !pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://aerodatabox.p.rapidapi.com/flights/airports/iata/LHR/2023-09-01T20:00/2023-09-02T08:00"

querystring = {"withLeg":"false","direction":"Both","withCodeshared":"true","withPrivate":"false"}

headers = {
    'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
    'x-rapidapi-key': "9613ca6ca5msh62659872159916fp1a0a2cjsndd9a3e6ff324"
    }

response = requests.get(url, headers=headers, params=querystring)

result = response.json()
result
# Out:
# {'departures': [{'movement': {'airport': {'icao': 'LIPZ',
#      'iata': 'VCE',
#      'name': 'Venice'},
#     'scheduledTimeLocal': '2023-09-01 18:40+01:00',
#     'actualTimeLocal': '2023-09-01 20:02+01:00',
#     'scheduledTimeUtc': '2023-09-01 17:40Z',
#     'actualTimeUtc': '2023-09-01 19:02Z',
#     'scheduledTime': {'utc': '2023-09-01 17:40Z',
#      'local': '2023-09-01 18:40+01:00'},
#     'revisedTime': {'utc': '2023-09-01 19:02Z',
#      'local': '2023-09-01 20:02+01:00'},
#     'terminal': '5',
#     'checkInDesk': 'C',
#     'quality': ['Basic', 'Live']},
#    'number': 'AA 6406',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'American', 'iata': 'AA', 'icao': 'AAL'}},
#   {'movement': {'airport': {'icao': 'EGAC', 'iata': 'BHD', 'name': 'Belfast'},
#     'scheduledTimeLocal': '2023-09-01 18:15+01:00',
#     'actualTimeLocal': '2023-09-01 20:13+01:00',
# ...

# %%
r_json = response.json()
r_json['departures']
# Out:
# [{'movement': {'airport': {'icao': 'LIPZ', 'iata': 'VCE', 'name': 'Venice'},
#    'scheduledTimeLocal': '2023-09-01 18:40+01:00',
#    'actualTimeLocal': '2023-09-01 20:02+01:00',
#    'scheduledTimeUtc': '2023-09-01 17:40Z',
#    'actualTimeUtc': '2023-09-01 19:02Z',
#    'scheduledTime': {'utc': '2023-09-01 17:40Z',
#     'local': '2023-09-01 18:40+01:00'},
#    'revisedTime': {'utc': '2023-09-01 19:02Z',
#     'local': '2023-09-01 20:02+01:00'},
#    'terminal': '5',
#    'checkInDesk': 'C',
#    'quality': ['Basic', 'Live']},
#   'number': 'AA 6406',
#   'status': 'Departed',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'model': 'Airbus A320'},
#   'airline': {'name': 'American', 'iata': 'AA', 'icao': 'AAL'}},
#  {'movement': {'airport': {'icao': 'EGAC', 'iata': 'BHD', 'name': 'Belfast'},
#    'scheduledTimeLocal': '2023-09-01 18:15+01:00',
#    'actualTimeLocal': '2023-09-01 20:13+01:00',
#    'scheduledTimeUtc': '2023-09-01 17:15Z',
# ...

# %%
df_departures = pd.json_normalize(r_json['departures'])
df_departures
# Out:
#       number    status codeshareStatus  isCargo movement.airport.icao  \
# 0    AA 6406  Departed    IsCodeshared    False                  LIPZ
# 1    AA 6539  Departed    IsCodeshared    False                  EGAC
# 2    BA 1424  Departed      IsOperator    False                  EGAC
# 3    BA 8441  Departed    IsCodeshared    False                  GMMN
# 4    EI 8314  Departed    IsCodeshared    False                  EGAC
# ..       ...       ...             ...      ...                   ...
# 542  QR 2218  Departed    IsCodeshared    False                  KBOS
# 543   BA 412  Departed      IsOperator    False                  LEMG
# 544   BA 678  Departed      IsOperator    False                  LTBS
# 545  BA 1306  Canceled      IsOperator    False                  EGPD
# 546  LH 2485  Departed      IsOperator    False                  EDDM
#
#     movement.airport.iata movement.airport.name movement.scheduledTimeLocal  \
# ...

# %%
df_departures[['number', 'movement.airport.iata', 'movement.airport.name']]
# Out:
#       number movement.airport.iata movement.airport.name
# 0    AA 6406                   VCE                Venice
# 1    AA 6539                   BHD               Belfast
# 2    BA 1424                   BHD               Belfast
# 3    BA 8441                   CMN            Casablanca
# 4    EI 8314                   BHD               Belfast
# ..       ...                   ...                   ...
# 542  QR 2218                   BOS                Boston
# 543   BA 412                   AGP                Málaga
# 544   BA 678                   DLM               Dalaman
# 545  BA 1306                   ABZ              Aberdeen
# 546  LH 2485                   MUC                Munich
#
# [547 rows x 3 columns]

# %%
r_json['arrivals']
# Out:
# [{'movement': {'airport': {'icao': 'VGSY', 'iata': 'ZYL', 'name': 'Sylhet'},
#    'scheduledTimeLocal': '2023-09-01 15:55+01:00',
#    'actualTimeLocal': '2023-09-01 20:06+01:00',
#    'runwayTimeLocal': '2023-09-01 20:06+01:00',
#    'scheduledTimeUtc': '2023-09-01 14:55Z',
#    'actualTimeUtc': '2023-09-01 19:06Z',
#    'runwayTimeUtc': '2023-09-01 19:06Z',
#    'scheduledTime': {'utc': '2023-09-01 14:55Z',
#     'local': '2023-09-01 15:55+01:00'},
#    'revisedTime': {'utc': '2023-09-01 19:06Z',
#     'local': '2023-09-01 20:06+01:00'},
#    'runwayTime': {'utc': '2023-09-01 19:06Z',
#     'local': '2023-09-01 20:06+01:00'},
#    'terminal': '4',
#    'baggageBelt': '6',
#    'quality': ['Basic', 'Live']},
#   'number': 'BG 201',
#   'callSign': 'BBC201',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'S2-AJY', 'modeS': '70209F', 'model': 'Boeing 787-9'},
# ...

# %%
df_arrivals = pd.json_normalize(r_json['arrivals'])
df_arrivals
# Out:
#       number callSign   status codeshareStatus  isCargo movement.airport.icao  \
# 0     BG 201   BBC201  Arrived      IsOperator    False                  VGSY
# 1    AA 6748      NaN  Arrived    IsCodeshared    False                  EBBR
# 2     BA 397   BAW397  Arrived      IsOperator    False                  EBBR
# 3    JL 7704      NaN  Arrived    IsCodeshared    False                  EBBR
# 4    MH 9721      NaN  Arrived    IsCodeshared    False                  EBBR
# ..       ...      ...      ...             ...      ...                   ...
# 644  UU 8680      NaN  Arrived    IsCodeshared    False                  LFPG
# 645  JL 7126      NaN  Arrived    IsCodeshared    False                  EGAC
# 646  AA 6633      NaN  Arrived    IsCodeshared    False                  LFLL
# 647  AC 5876      NaN  Arrived    IsCodeshared    False                  KEWR
# 648  AC 6969      NaN  Arrived    IsCodeshared    False                  EDDH
#
# ...

# %%
df_arrivals[['number', 'movement.airport.iata', 'movement.airport.name']]
# Out:
#       number movement.airport.iata movement.airport.name
# 0     BG 201                   ZYL                Sylhet
# 1    AA 6748                   BRU              Brussels
# 2     BA 397                   BRU              Brussels
# 3    JL 7704                   BRU              Brussels
# 4    MH 9721                   BRU              Brussels
# ..       ...                   ...                   ...
# 644  UU 8680                   CDG                 Paris
# 645  JL 7126                   BHD               Belfast
# 646  AA 6633                   LYS                  Lyon
# 647  AC 5876                   EWR                Newark
# 648  AC 6969                   HAM               Hamburg
#
# [649 rows x 3 columns]
